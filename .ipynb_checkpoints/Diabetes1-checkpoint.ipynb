# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
cols=["age","gender","fam_diabetes","highBP","pActivity","bmi","smoking","alcohol","sleep","soundSleep","medicine","junk_food","stress","BP_level","pregnancies","Pdiabetes","urine_freq","diabetic"]
df=pd.read_csv("diabetes_dataset__2019.csv",names=cols).drop(["highBP","Pdiabetes"],axis=1)
df=df.drop(df.index[0:1])
df.head()
# Out:
#      age gender fam_diabetes             pActivity bmi smoking alcohol sleep  \
# 1  50-59   Male           no        one hr or more  39      no      no     8
# 2  50-59   Male           no  less than half an hr  28      no      no     8
# 3  40-49   Male           no        one hr or more  24      no      no     6
# 4  50-59   Male           no        one hr or more  23      no      no     8
# 5  40-49   Male           no  less than half an hr  27      no      no     8
#
#   soundSleep medicine     junk_food     stress BP_level pregnancies  \
# 1          6       no  occasionally  sometimes     high           0
# 2          6      yes    very often  sometimes   normal           0
# 3          6       no  occasionally  sometimes   normal           0
# 4          6       no  occasionally  sometimes   normal           0
# 5          8       no  occasionally  sometimes   normal           0
#
#   urine_freq diabetic
# 1   not much       no
# 2   not much       no
# 3   not much       no
# 4   not much       no
# 5   not much       no

# %% [markdown]
# # Pre-processing

# %%
df=df.dropna()
for column in df.columns:
  print("unique values in "+column+" are: ",end="")
  print(df[column].unique())
# Out:
# unique values in age are: ['50-59' '40-49' 'less than 40' '60 or older']
# unique values in gender are: ['Male' 'Female']
# unique values in fam_diabetes are: ['no' 'yes']
# unique values in pActivity are: ['one hr or more' 'less than half an hr' 'none' 'more than half an hr']
# unique values in bmi are: ['39' '28' '24' '23' '27' '21' '20' '26' '22' '15' '34' '30' '29' '18'
#  '32' '31' '36' '38' '40' '35' '19' '33' '17' '25' '42' '45']
# unique values in smoking are: ['no' 'yes']
# unique values in alcohol are: ['no' 'yes']
# unique values in sleep are: ['8' '6' '10' '7' '11' '9' '4' '5']
# unique values in soundSleep are: ['6' '8' '10' '7' '11' '4' '9' '5' '3' '2' '6 ' '1' '0']
# unique values in medicine are: ['no' 'yes' 'o']
# unique values in junk_food are: ['occasionally' 'very often' 'often' 'always']
# unique values in stress are: ['sometimes' 'not at all' 'very often' 'always']
# unique values in BP_level are: ['high' 'normal' 'low' 'Low' 'High' 'normal ']
# unique values in pregnancies are: ['0' '1' '2' '3' '4']
# unique values in urine_freq are: ['not much' 'quite often']
# unique values in diabetic are: ['no' 'yes' ' no']

# %%
df["gender"]=(df["gender"]=="Male").astype(int)
df["fam_diabetes"]=(df["fam_diabetes"]=="yes").astype(int)
df["smoking"]=(df["smoking"]=="yes").astype(int)
df["alcohol"]=(df["alcohol"]=="yes").astype(int)
df["medicine"]=df["medicine"].replace("o","no")
df["medicine"]=(df["medicine"]=="yes").astype(int)
df["BP_level"]=df["BP_level"].replace("High","high")
df["BP_level"]=df["BP_level"].replace("Low","low")
df["BP_level"]=df["BP_level"].replace("normal ","normal")
df["diabetic"]=df["diabetic"].replace(" no","no")
df["urine_freq"]=(df["urine_freq"]=="quite often").astype(int)
df["diabetic"]=(df["diabetic"]=="yes").astype(int)
df["bmi"]=pd.to_numeric(df["bmi"],errors="coerce")
df["sleep"]=pd.to_numeric(df["sleep"],errors="coerce")
df["soundSleep"]=pd.to_numeric(df["soundSleep"],errors="coerce")
df["pregnancies"]=pd.to_numeric(df["pregnancies"],errors="coerce")

# %%
for column in df.columns:
  print("unique values in "+column+" are: ",end="")
  print(df[column].unique())
# Out:
# unique values in age are: ['50-59' '40-49' 'less than 40' '60 or older']
# unique values in gender are: [1 0]
# unique values in fam_diabetes are: [0 1]
# unique values in pActivity are: ['one hr or more' 'less than half an hr' 'none' 'more than half an hr']
# unique values in bmi are: [39 28 24 23 27 21 20 26 22 15 34 30 29 18 32 31 36 38 40 35 19 33 17 25
#  42 45]
# unique values in smoking are: [0 1]
# unique values in alcohol are: [0 1]
# unique values in sleep are: [ 8  6 10  7 11  9  4  5]
# unique values in soundSleep are: [ 6  8 10  7 11  4  9  5  3  2  1  0]
# unique values in medicine are: [0 1]
# unique values in junk_food are: ['occasionally' 'very often' 'often' 'always']
# unique values in stress are: ['sometimes' 'not at all' 'very often' 'always']
# unique values in BP_level are: ['high' 'normal' 'low']
# unique values in pregnancies are: [0 1 2 3 4]
# unique values in urine_freq are: [0 1]
# unique values in diabetic are: [0 1]

# %%
encoded=pd.get_dummies(df["age"],prefix="age",dtype=int)
df=pd.concat([encoded,df],axis=1)
df=df.drop("age",axis=1)
encoded=pd.get_dummies(df["pActivity"],prefix="pActivity",dtype=int)
df=pd.concat([encoded,df],axis=1)
df=df.drop("pActivity",axis=1)
encoded=pd.get_dummies(df["junk_food"],prefix="junk_food",dtype=int)
df=pd.concat([encoded,df],axis=1)
df=df.drop("junk_food",axis=1)
encoded=pd.get_dummies(df["stress"],prefix="stress",dtype=int)
df=pd.concat([encoded,df],axis=1)
df=df.drop("stress",axis=1)
encoded=pd.get_dummies(df["BP_level"],prefix="BP_level",dtype=int)
df=pd.concat([encoded,df],axis=1)
df=df.drop("BP_level",axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(df[df.columns[:-1]],df[df.columns[-1]],test_size=0.2,random_state=42)

# %%
def scale_dataset(x,y,oversample=False):
  scaler=StandardScaler()
  x=scaler.fit_transform(x)
  if oversample:
    ros=RandomOverSampler(random_state=42)
    x,y=ros.fit_resample(x,y)
  return x,y

# %%
x_train,y_train=scale_dataset(x_train,y_train,oversample=True)
x_test,y_test=scale_dataset(x_test,y_test)

# %% [markdown]
# # Models

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

# %%
grid_params={"n_neighbors":[1,3,5,7,9],"weights":["uniform","distance"],"p":[1,2,3]}
clf=GridSearchCV(KNeighborsClassifier(),grid_params,cv=5)
clf.fit(x_train,y_train)
result_df=pd.DataFrame(clf.cv_results_)
print("Best score=",clf.best_score_)
print("Best parameters: ",clf.best_params_)
best_model=clf.best_estimator_

#using the model with best parameters

knn_model=best_model
knn_model.fit(x_train,y_train)
y_pred=knn_model.predict(x_test)
print(classification_report(y_test,y_pred))
auc=roc_auc_score(y_test,y_pred)
print("AUC: ",auc)
# Out:
# Best score= 0.9533080748283211
# Best parameters:  {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       129
#            1       0.91      0.96      0.94        53
#
#     accuracy                           0.96       182
#    macro avg       0.95      0.96      0.95       182
# weighted avg       0.96      0.96      0.96       182
#
# AUC:  0.9617522305104579

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model=GaussianNB()
nb_model=nb_model.fit(x_train,y_train)
y_pred=nb_model.predict(x_test)
print(classification_report(y_test,y_pred))
auc=roc_auc_score(y_test,y_pred)
print("AUC: ",auc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83       129
#            1       0.00      0.00      0.00        53
#
#     accuracy                           0.71       182
#    macro avg       0.35      0.50      0.41       182
# weighted avg       0.50      0.71      0.59       182
#
# AUC:  0.5
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
grid_params ={'penalty' : ['l2'],
    'C' : [0.001,0.01,0.1,1,10,100],
    'solver' : ['lbfgs','newton-cg','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }

clf=GridSearchCV(LogisticRegression(),grid_params,cv=5)
clf.fit(x_train,y_train)
result_df=pd.DataFrame(clf.cv_results_)
print("Best score=",clf.best_score_)
print("Best parameters: ",clf.best_params_)

#using best hyperparameters
log_reg_best=clf.best_estimator_
log_reg_best.fit(x_train,y_train)
y_pred=log_reg_best.predict(x_test)
print(classification_report(y_test,y_pred))
auc=roc_auc_score(y_test,y_pred)
print("AUC: ",auc)
# Out:
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\subha\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best score= 0.8570068671560502
# Best parameters:  {'C': 0.01, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89       129
#            1       0.71      0.79      0.75        53
#
#     accuracy                           0.85       182
#    macro avg       0.81      0.83      0.82       182
# weighted avg       0.85      0.85      0.85       182
#
# AUC:  0.8303349422261226

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# %%
grid_params = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}
clf=GridSearchCV(SVC(),grid_params,cv=5)
clf.fit(x_train,y_train)
result_df=pd.DataFrame(clf.cv_results_)
print("Best score=",clf.best_score_)
print("Best parameters: ",clf.best_params_)

#using best hyperparameters
svm_best=clf.best_estimator_
svm_best.fit(x_train,y_train)
y_pred=svm_best.predict(x_test)
print(classification_report(y_test,y_pred))
auc=roc_auc_score(y_test,y_pred)
print("AUC: ",auc)
# Out:
# Best score= 0.9523324650722236
# Best parameters:  {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       129
#            1       0.93      0.96      0.94        53
#
#     accuracy                           0.97       182
#    macro avg       0.96      0.97      0.96       182
# weighted avg       0.97      0.97      0.97       182
#
# AUC:  0.9656281995027058

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
grid_params={
    "criterion":["gini","entropy","log_loss"],
    "splitter":["best","random"],
    "max_depth":[None,1,2,3,4,5,7],
    "max_features":["sqrt","log2",0.5,1,3,5,None]
}
clf=GridSearchCV(DecisionTreeClassifier(),grid_params,cv=5)
clf.fit(x_train,y_train)
result_df=pd.DataFrame(clf.cv_results_)
print("Best score=",clf.best_score_)
print("Best parameters: ",clf.best_params_)

#using best hyperparameterd
dt_best=clf.best_estimator_
dt_best.fit(x_train,y_train)
y_pred=dt_best.predict(x_test)
print(classification_report(y_test,y_pred))
auc=roc_auc_score(y_test,y_pred)
print("AUC: ",auc)
# Out:
# Best score= 0.954274212645039
# Best parameters:  {'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'splitter': 'random'}
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88       129
#            1       0.68      0.77      0.73        53
#
#     accuracy                           0.83       182
#    macro avg       0.79      0.81      0.80       182
# weighted avg       0.84      0.83      0.83       182
#
# AUC:  0.8131490419774755

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
grid_params={
    "n_estimators":[50,100,200],
    "criterion":["gini","entropy","log_loss"],
    "max_features":["sqrt","log2",0.5,1,3,5,None],
    "n_jobs":[-1]
}
clf=GridSearchCV(RandomForestClassifier(),grid_params,cv=5)
clf.fit(x_train,y_train)
result_df=pd.DataFrame(clf.cv_results_)
print("Best score=",clf.best_score_)
print("Best parameters: ",clf.best_params_)

#using best hyperparameters
rf_best=clf.best_estimator_
rf_best.fit(x_train,y_train)
y_pred=rf_best.predict(x_test)
print(classification_report(y_test,y_pred))
auc=roc_auc_score(y_test,y_pred)
print("AUC: ",auc)
# Out:
# Best score= 0.9610940089983424
# Best parameters:  {'criterion': 'log_loss', 'max_features': 0.5, 'n_estimators': 200, 'n_jobs': -1}
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       129
#            1       0.93      0.96      0.94        53
#
#     accuracy                           0.97       182
#    macro avg       0.96      0.97      0.96       182
# weighted avg       0.97      0.97      0.97       182
#
# AUC:  0.9656281995027058

# %% [markdown]
# ## Neural Network

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout

# %%
pip install -U keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\subha\miniconda3\envs\tf\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\subha\miniconda3\envs\tf\lib\site-packages (from keras-tuner) (2.10.0)
# Requirement already satisfied: packaging in c:\users\subha\miniconda3\envs\tf\lib\site-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in c:\users\subha\miniconda3\envs\tf\lib\site-packages (from keras-tuner) (2.32.2)
# Requirement already satisfied: kt-legacy in c:\users\subha\miniconda3\envs\tf\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\subha\miniconda3\envs\tf\lib\site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\subha\miniconda3\envs\tf\lib\site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\subha\miniconda3\envs\tf\lib\site-packages (from requests->keras-tuner) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\subha\miniconda3\envs\tf\lib\site-packages (from requests->keras-tuner) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import keras_tuner as kt
from tensorflow.keras.optimizers import SGD, RMSprop, Adam

# %%
def build_model(hp):
    nn_model = Sequential()
    count = 0
    for i in range(hp.Int('num_layers', min_value=1, max_value=4)):
        if count == 0:
            nn_model.add(Dense(hp.Int('num_nodes' + str(i), min_value=32, max_value=128, step=32),
                               activation='relu',
                               input_dim=x_train.shape[1]))
        else:
            nn_model.add(Dense(hp.Int('num_nodes' + str(i), min_value=32, max_value=128, step=32),
                               activation='relu'))
        count += 1

    nn_model.add(Dense(1, activation='sigmoid'))
    
    # Define optimizer with the specified learning rate
    optimizer_choice = hp.Choice('optimizer', values=['SGD', 'RMSprop', 'Adam'])
    learning_rate = hp.Choice('learning_rate', values=[1e-4])  # Add different learning rates
    if optimizer_choice == 'SGD':
        optimizer = SGD(learning_rate=learning_rate)
    elif optimizer_choice == 'RMSprop':
        optimizer = RMSprop(learning_rate=learning_rate)
    else:
        optimizer = Adam(learning_rate=learning_rate)

    nn_model.compile(optimizer=optimizer,
                     loss='binary_crossentropy',
                     metrics=['accuracy'])
    return nn_model

# %%
tuner=kt.GridSearch(build_model, objective= 'val_accuracy',directory="mydir",project_name="dib5")
tuner.search(x_train,y_train,epochs=5, validation_split=0.2)
# Out:
# Trial 29 Complete [00h 00m 03s]
# val_accuracy: 0.5339806079864502
#
# Best val_accuracy So Far: 0.9902912378311157
# Total elapsed time: 00h 01m 18s
#
# Search: Running Trial #30
#
# Value             |Best Value So Far |Hyperparameter
# 2                 |2                 |num_layers
# 64                |32                |num_nodes0
# RMSprop           |Adam              |optimizer
# 0.0001            |0.0001            |learning_rate
# 64                |96                |num_nodes1
# Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x000001E69DC50700>
# Traceback (most recent call last):
#   File "C:\Users\subha\miniconda3\envs\tf\lib\weakref.py", line 371, in remove
#     self = selfref()
# KeyboardInterrupt:
# Epoch 1/5
#  1/26 [>.............................] - ETA: 8s - loss: 0.6956 - accuracy: 0.5312WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0039s vs `on_train_batch_end` time: 0.0040s). Check your callbacks.
# 26/26 [==============================] - 1s 12ms/step - loss: 0.6633 - accuracy: 0.5900 - val_loss: 0.7651 - val_accuracy: 0.2476
# Epoch 2/5
# 22/26 [========================>.....] - ETA: 0s - loss: 0.6280 - accuracy: 0.6634
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[125], line 2
#       1 tuner=kt.GridSearch(build_model, objective= 'val_accuracy',directory="mydir",project_name="dib5")
# ----> 2 tuner.search(x_train,y_train,epochs=5, validation_split=0.2)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras_tuner\src\engine\base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras_tuner\src\engine\base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras_tuner\src\engine\base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras_tuner\src\engine\tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras_tuner\src\engine\hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:1624, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1619     val_logs = {
#    1620         "val_" + name: val for name, val in val_logs.items()
#    1621     }
#    1622     epoch_logs.update(val_logs)
# -> 1624 callbacks.on_epoch_end(epoch, epoch_logs)
#    1625 training_logs = epoch_logs
#    1626 if self.stop_training:
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\callbacks.py:448, in CallbackList.on_epoch_end(self, epoch, logs)
#     446 logs = self._process_logs(logs)
#     447 for callback in self.callbacks:
# --> 448     callback.on_epoch_end(epoch, logs)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras_tuner\src\engine\tuner_utils.py:76, in SaveBestEpoch.on_epoch_end(self, epoch, logs)
#      74 if self.objective.better_than(current_value, self.best_value):
#      75     self.best_value = current_value
# ---> 76     self._save_model()
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras_tuner\src\engine\tuner_utils.py:86, in SaveBestEpoch._save_model(self)
#      82 # Create temporary saved model files on non-chief workers.
#      83 write_filepath = backend.io.write_filepath(
#      84     self.filepath, self.model.distribute_strategy
#      85 )
# ---> 86 self.model.save_weights(write_filepath)
#      87 # Remove temporary saved model files on non-chief workers.
#      88 backend.io.remove_temp_dir_with_filepath(
#      89     write_filepath, self.model.distribute_strategy
#      90 )
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:2824, in Model.save_weights(self, filepath, overwrite, save_format, options)
#    2820 self._checkpoint.write(filepath, options=options)
#    2822 # Record this checkpoint so it's visible from
#    2823 # tf.train.latest_checkpoint.
# -> 2824 tf.__internal__.train.update_checkpoint_state(
#    2825     save_dir=os.path.dirname(filepath),
#    2826     model_checkpoint_path=filepath,
#    2827     save_relative_paths=True,
#    2828     all_model_checkpoint_paths=[filepath],
#    2829 )
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\checkpoint\checkpoint_management.py:244, in update_checkpoint_state_internal(save_dir, model_checkpoint_path, all_model_checkpoint_paths, latest_filename, save_relative_paths, all_model_checkpoint_timestamps, last_preserved_timestamp)
#     238   raise RuntimeError("Save path '%s' conflicts with path used for "
#     239                      "checkpoint state.  Please use a different save path." %
#     240                      model_checkpoint_path)
#     242 # Preventing potential read/write race condition by *atomically* writing to a
#     243 # file.
# --> 244 file_io.atomic_write_string_to_file(coord_checkpoint_filename,
#     245                                     text_format.MessageToString(ckpt))
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\lib\io\file_io.py:643, in atomic_write_string_to_file(filename, contents, overwrite)
#     641 else:
#     642   temp_pathname = filename + ".tmp" + uuid.uuid4().hex
# --> 643   write_string_to_file(temp_pathname, contents)
#     644   try:
#     645     rename(temp_pathname, filename, overwrite)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\lib\io\file_io.py:363, in write_string_to_file(filename, file_content)
#     353 """Writes a string to a given file.
#     354
#     355 Args:
#    (...)
#     360   errors.OpError: If there are errors during the operation.
#     361 """
#     362 with FileIO(filename, mode="w") as f:
# --> 363   f.write(file_content)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\lib\io\file_io.py:197, in FileIO.__exit__(self, unused_type, unused_value, unused_traceback)
#     195 def __exit__(self, unused_type, unused_value, unused_traceback):
#     196   """Make usable with "with" statement."""
# --> 197   self.close()
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\lib\io\file_io.py:239, in FileIO.close(self)
#     237 self._read_buf = None
#     238 if self._writable_file:
# --> 239   self._writable_file.close()
#     240   self._writable_file = None
#
# KeyboardInterrupt:

# %%
result=[]
for i in range(1,20):
    model=tuner.get_best_models(num_models=i)[i-1]
    model.fit(x_train,y_train,epochs=100,initial_epoch=5,validation_data=(x_test,y_test))
    result.append(f"model {i}: {model.evaluate(x_test,y_test)}")
# Out:
# Epoch 6/100
# 33/33 [==============================] - 1s 9ms/step - loss: 0.0746 - accuracy: 0.9669 - val_loss: 0.1450 - val_accuracy: 0.9560
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0833 - accuracy: 0.9591 - val_loss: 0.1337 - val_accuracy: 0.9451
# Epoch 8/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0737 - accuracy: 0.9621 - val_loss: 0.1420 - val_accuracy: 0.9560
# Epoch 9/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0794 - accuracy: 0.9621 - val_loss: 0.1980 - val_accuracy: 0.9560
# Epoch 10/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0748 - accuracy: 0.9591 - val_loss: 0.1466 - val_accuracy: 0.9505
# Epoch 11/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0781 - accuracy: 0.9640 - val_loss: 0.1300 - val_accuracy: 0.9505
# Epoch 12/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0746 - accuracy: 0.9630 - val_loss: 0.1328 - val_accuracy: 0.9560
# Epoch 13/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0677 - accuracy: 0.9660 - val_loss: 0.1732 - val_accuracy: 0.9505
# Epoch 14/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0765 - accuracy: 0.9582 - val_loss: 0.1343 - val_accuracy: 0.9560
# Epoch 15/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0719 - accuracy: 0.9650 - val_loss: 0.1461 - val_accuracy: 0.9560
# Epoch 16/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0699 - accuracy: 0.9640 - val_loss: 0.1545 - val_accuracy: 0.9451
# Epoch 17/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0689 - accuracy: 0.9689 - val_loss: 0.1303 - val_accuracy: 0.9560
# Epoch 18/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0722 - accuracy: 0.9679 - val_loss: 0.1315 - val_accuracy: 0.9560
# Epoch 19/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0662 - accuracy: 0.9679 - val_loss: 0.1509 - val_accuracy: 0.9451
# Epoch 20/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0668 - accuracy: 0.9630 - val_loss: 0.1323 - val_accuracy: 0.9505
# Epoch 21/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0679 - accuracy: 0.9621 - val_loss: 0.1661 - val_accuracy: 0.9505
# Epoch 22/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0663 - accuracy: 0.9660 - val_loss: 0.1395 - val_accuracy: 0.9560
# Epoch 23/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0668 - accuracy: 0.9650 - val_loss: 0.1371 - val_accuracy: 0.9560
# Epoch 24/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0650 - accuracy: 0.9650 - val_loss: 0.1344 - val_accuracy: 0.9615
# Epoch 25/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0642 - accuracy: 0.9621 - val_loss: 0.1447 - val_accuracy: 0.9505
# Epoch 26/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0635 - accuracy: 0.9669 - val_loss: 0.1566 - val_accuracy: 0.9560
# Epoch 27/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0654 - accuracy: 0.9689 - val_loss: 0.1622 - val_accuracy: 0.9505
# Epoch 28/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0647 - accuracy: 0.9679 - val_loss: 0.1373 - val_accuracy: 0.9615
# Epoch 29/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0607 - accuracy: 0.9679 - val_loss: 0.1953 - val_accuracy: 0.9451
# Epoch 30/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0653 - accuracy: 0.9669 - val_loss: 0.1399 - val_accuracy: 0.9615
# Epoch 31/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.
100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0811 - accuracy: 0.9630 - val_loss: 0.1282 - val_accuracy: 0.9615
# Epoch 13/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0758 - accuracy: 0.9660 - val_loss: 0.1202 - val_accuracy: 0.9670
# Epoch 14/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0711 - accuracy: 0.9660 - val_loss: 0.1325 - val_accuracy: 0.9615
# Epoch 15/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0727 - accuracy: 0.9630 - val_loss: 0.1150 - val_accuracy: 0.9560
# Epoch 16/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0705 - accuracy: 0.9601 - val_loss: 0.1418 - val_accuracy: 0.9505
# Epoch 17/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0706 - accuracy: 0.9689 - val_loss: 0.1286 - val_accuracy: 0.9560
# Epoch 18/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0647 - accuracy: 0.9708 - val_loss: 0.1709 - val_accuracy: 0.9505
# Epoch 19/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0674 - accuracy: 0.9698 - val_loss: 0.1363 - val_accuracy: 0.9560
# Epoch 20/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0645 - accuracy: 0.9718 - val_loss: 0.1000 - val_accuracy: 0.9670
# Epoch 21/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0630 - accuracy: 0.9679 - val_loss: 0.1348 - val_accuracy: 0.9505
# Epoch 22/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0637 - accuracy: 0.9679 - val_loss: 0.1370 - val_accuracy: 0.9560
# Epoch 23/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0642 - accuracy: 0.9689 - val_loss: 0.1593 - val_accuracy: 0.9505
# Epoch 24/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0601 - accuracy: 0.9718 - val_loss: 0.1397 - val_accuracy: 0.9505
# Epoch 25/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0629 - accuracy: 0.9660 - val_loss: 0.1284 - val_accuracy: 0.9615
# Epoch 26/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0627 - accuracy: 0.9698 - val_loss: 0.1182 - val_accuracy: 0.9505
# Epoch 27/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 0.9718 - val_loss: 0.1357 - val_accuracy: 0.9560
# Epoch 28/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0568 - accuracy: 0.9679 - val_loss: 0.1480 - val_accuracy: 0.9560
# Epoch 29/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0604 - accuracy: 0.9698 - val_loss: 0.1559 - val_accuracy: 0.9560
# Epoch 30/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0565 - accuracy: 0.9708 - val_loss: 0.1540 - val_accuracy: 0.9505
# Epoch 31/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 0.9669 - val_loss: 0.1765 - val_accuracy: 0.9615
# Epoch 32/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0590 - accuracy: 0.9708 - val_loss: 0.2006 - val_accuracy: 0.9505
# Epoch 33/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0562 - accuracy: 0.9689 - val_loss: 0.1877 - val_accuracy: 0.9560
# Epoch 34/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0610 - accuracy: 0.9728 - val_loss: 0.1789 - val_accuracy: 0.9560
# Epoch 35/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0564 - accuracy: 0.9698 - val_loss: 0.1733 - val_accuracy: 0.9560
# Epoch 36/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0537 - accuracy: 0.9708 - val_loss: 0.2408 - val_accuracy: 0.9615
# Epoch 37/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0610 - accuracy: 0.9679 - val_loss: 0.1872 - val_accuracy: 0.9505
# Epoch 38/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0552 - accuracy: 0.9689 - val_loss: 0.1838 - val_accuracy: 0.9505
# Epoch 39/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.9708 - val_loss: 0.1950 - val_accuracy: 0.9505
# Epoch 40/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0583 - accuracy: 0.9679 - val_loss: 0.1889 - val_accuracy: 0.9560
# Epoch 41/100
# 14/33 [===========>..................] - ETA: 0s - loss: 0.0357 - accuracy: 0.9844
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 4
#       2 for i in range(1,20):
#       3     model=tuner.get_best_models(num_models=i)[i-1]
# ----> 4     model.fit(x_train,y_train,epochs=100,initial_epoch=5,validation_data=(x_test,y_test))
#       5     result.append(f"model {i}: {model.evaluate(x_test,y_test)}")
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:1555, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1551 with data_handler.catch_stop_iteration():
#    1552     data_handler._initial_step = data_handler._initial_step or (
#    1553         self._maybe_load_initial_step_from_ckpt()
#    1554     )
# -> 1555     for step in data_handler.steps():
#    1556         with tf.profiler.experimental.Trace(
#    1557             "train",
#    1558             epoch_num=epoch,
#    (...)
#    1561             _r=1,
#    1562         ):
#    1563             callbacks.on_train_batch_begin(step)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\data_adapter.py:1374, in DataHandler.steps(self)
#    1372 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1373     break
# -> 1374 original_spe = self._steps_per_execution.numpy().item()
#    1375 can_run_full_execution = (
#    1376     original_spe == 1
#    1377     or self._inferred_steps is None
#    1378     or self._inferred_steps - self._current_step >= original_spe
#    1379 )
#    1381 if can_run_full_execution:
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:637, in BaseResourceVariable.numpy(self)
#     635 def numpy(self):
#     636   if context.executing_eagerly():
# --> 637     return self.read_value().numpy()
#     638   raise NotImplementedError(
#     639       "numpy() is only available when eager execution is enabled.")
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
result
# Out:
# ['model 1: [0.3073215186595917, 0.9725274443626404]',
#  'model 2: [0.5148547291755676, 0.9560439586639404]',
#  'model 3: [0.15155695378780365, 0.9505494236946106]',
#  'model 4: [0.18674252927303314, 0.9615384340286255]',
#  'model 5: [0.14606580138206482, 0.9560439586639404]',
#  'model 6: [0.3570745289325714, 0.9615384340286255]',
#  'model 7: [0.3437439799308777, 0.9615384340286255]',
#  'model 8: [0.6385170221328735, 0.9725274443626404]',
#  'model 9: [0.28594180941581726, 0.9560439586639404]',
#  'model 10: [0.15249550342559814, 0.9505494236946106]',
#  'model 11: [0.44141605496406555, 0.9560439586639404]',
#  'model 12: [0.14456388354301453, 0.9615384340286255]',
#  'model 13: [0.29338720440864563, 0.9615384340286255]',
#  'model 14: [0.453723669052124, 0.9670329689979553]',
#  'model 15: [0.4493361711502075, 0.9615384340286255]',
#  'model 16: [0.1821203976869583, 0.9505494236946106]',
#  'model 17: [0.42640891671180725, 0.9560439586639404]',
#  'model 18: [0.41630494594573975, 0.9505494236946106]',
#  'model 19: [0.37043502926826477, 0.9395604133605957]']

# %%
model=tuner.get_best_models(num_models=1)[0]
model.fit(x_train,y_train,epochs=100,initial_epoch=5,validation_data=(x_test,y_test))
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer